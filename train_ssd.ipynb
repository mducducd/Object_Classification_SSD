# %%
import torch

# !nvidia-smi
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #enable if u have gpu
# device = torch.device("cpu")
print("device:", device)
# Out:
# Mon Sep 21 12:43:39 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/mducducd/Object_Detection_SSD300.git
# Out:
# Cloning into 'Object_Detection_SSD300'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 37 (delta 4), reused 29 (delta 0), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
cd /content/Object_Detection_SSD300
# Out:
# /content/Object_Detection_SSD300

# %%
# !python prepare_data.py

# %%
cd /content/Object_Detection_SSD300/data
# Out:
# /content/Object_Detection_SSD300/data

# %%
# !mkdir weights

# %%
cd /content/Object_Detection_SSD300/data/weights
# Out:
# /content/Object_Detection_SSD300/data/weights

# %%
# !wget https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Out:
# --2020-09-21 12:52:02--  https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.244.126
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.244.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81938914 (78M) [binary/octet-stream]
# Saving to: ‘vgg16_reducedfc.pth’
#
# vgg16_reducedfc.pth 100%[===================>]  78.14M  36.7MB/s    in 2.1s
#
# 2020-09-21 12:52:04 (36.7 MB/s) - ‘vgg16_reducedfc.pth’ saved [81938914/81938914]

# %%
cd /content/Object_Detection_SSD300
# Out:
# /content/Object_Detection_SSD300

# %%
# !python train.py
# Out:
# device: cuda:0
# ------------------------------------------------------------
# Epoch 1/30
# ------------------------------------------------------------
# (Training)
# Iteration 10 || Loss: 14.3853 || 10iter: 23.4182 sec
# Iteration 20 || Loss: 10.8298 || 10iter: 15.1483 sec
# Iteration 30 || Loss: 9.9807 || 10iter: 15.8217 sec
# Iteration 40 || Loss: 10.5144 || 10iter: 15.3080 sec
# Iteration 50 || Loss: 9.4361 || 10iter: 15.1043 sec
# Iteration 60 || Loss: 9.1768 || 10iter: 14.8860 sec
# Iteration 70 || Loss: 8.9693 || 10iter: 15.2222 sec
# Iteration 80 || Loss: 8.4401 || 10iter: 15.1969 sec
# Iteration 90 || Loss: 9.1413 || 10iter: 15.1249 sec
# Iteration 100 || Loss: 8.6895 || 10iter: 14.8817 sec
# Iteration 110 || Loss: 8.5875 || 10iter: 15.4638 sec
# Iteration 120 || Loss: 8.3523 || 10iter: 15.2619 sec
# Iteration 130 || Loss: 8.2179 || 10iter: 14.9659 sec
# Iteration 140 || Loss: 7.9934 || 10iter: 14.7576 sec
# Iteration 150 || Loss: 8.8160 || 10iter: 15.2693 sec
# ...
